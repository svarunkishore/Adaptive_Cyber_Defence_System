# %% [markdown]
# <a href="https://colab.research.google.com/github/svarunkishore/Adaptive_Cyber_Defence_System/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Embedding, LSTM
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from sklearn.preprocessing import LabelEncoder
dataset_df = pd.read_csv('/content/android_dataset-v2.csv')

# %%
Y = dataset_df['class']
X = dataset_df.drop(['class'], axis=1)
encoder = LabelEncoder().fit(Y)
Y = encoder.transform(Y)
#print(encoder.transform(['malign']))
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
Y = dataset_df['class']
X = dataset_df.drop(['class'], axis=1)
features = X.columns

num_features = len(features)

# Print the list of feature names and the count of features
print("List of features:", features)
print("Number of features:", num_features)
# Out:
# List of features: Index(['android.permission.ACCESS_ALL_DOWNLOADS',
#        'android.permission.ACCESS_BLUETOOTH_SHARE',
#        'android.permission.ACCESS_CACHE_FILESYSTEM',
#        'android.permission.ACCESS_CHECKIN_PROPERTIES',
#        'android.permission.ACCESS_CONTENT_PROVIDERS_EXTERNALLY',
#        'android.permission.ACCESS_DOWNLOAD_MANAGER',
#        'android.permission.ACCESS_DOWNLOAD_MANAGER_ADVANCED',
#        'android.permission.ACCESS_DRM_CERTIFICATES',
#        'android.permission.ACCESS_EPHEMERAL_APPS',
#        'android.permission.ACCESS_FM_RADIO',
#        ...
#        'android.permission.RIDE_EXTERNAL_STORAGE',
#        'android.permission.RUN_INSTRUMENTATION',
#        'android.permission.ACTION_VIEW',
#        'android.permission.READ_CELL_BROADCASTS',
#        'android.permission.ROOT_RECOVERY_STATE',
#        'android.permission.QUICKBOOT_POWERON',
#        'android.permission.RECEIVE_BOOT_COMPLETE',
#        'android.permission.REQUEST_DELETE_PACKAGES',
#        'android.permission.ENABLE_KEYGUARD',
#        'android.permission.FOREGROUND_SERVICE'],
#       dtype='object', length=428)
# Number of features: 428

# %%
AN = Sequential()
AN.add(Dense(256, activation='relu', input_dim=428))
AN.add(Dropout(0.2))
AN.add(Dense(128, activation='relu'))
AN.add(Dropout(0.2))
AN.add(Dense(128, activation='relu'))
AN.add(Dropout(0.2))
AN.add(Dense(32, activation='relu'))
AN.add(Dropout(0.2))
AN.add(Dense(1, activation='sigmoid'))
AN.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

AN.fit(X_train, y_train, epochs=100, batch_size=32)


scores = AN.evaluate(X_test, y_test)
for i in range(len(scores)):
  print("\n%s: %.2f%%" % (AN.metrics_names[i], scores[i]*100))
# Out:
# Epoch 1/100
# 42/42 [==============================] - 2s 6ms/step - loss: 0.6747 - accuracy: 0.6627
# Epoch 2/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.6546 - accuracy: 0.6888
# Epoch 3/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.6332 - accuracy: 0.6895
# Epoch 4/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.6204 - accuracy: 0.6902
# Epoch 5/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.6063 - accuracy: 0.6910
# Epoch 6/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.5933 - accuracy: 0.6932
# Epoch 7/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.5743 - accuracy: 0.6940
# Epoch 8/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5576 - accuracy: 0.7059
# Epoch 9/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5405 - accuracy: 0.7275
# Epoch 10/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.7573
# Epoch 11/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.4957 - accuracy: 0.7818
# Epoch 12/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.4708 - accuracy: 0.8042
# Epoch 13/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4560 - accuracy: 0.8079
# Epoch 14/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4337 - accuracy: 0.8094
# Epoch 15/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.8206
# Epoch 16/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.8243
# Epoch 17/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4063 - accuracy: 0.8310
# Epoch 18/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4036 - accuracy: 0.8347
# Epoch 19/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3902 - accuracy: 0.8362
# Epoch 20/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3833 - accuracy: 0.8414
# Epoch 21/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8481
# Epoch 22/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3682 - accuracy: 0.8496
# Epoch 23/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3576 - accuracy: 0.8474
# Epoch 24/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8526
# Epoch 25/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3532 - accuracy: 0.8622
# Epoch 26/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3490 - accuracy: 0.8652
# Epoch 27/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.3367 - accuracy: 0.8712
# Epoch 28/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3336 - accuracy: 0.8697
# Epoch 29/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.3397 - accuracy: 0.8622
# Epoch 30/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3445 - accuracy: 0.8585
# Epoch 31/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3236 - accuracy: 0.8794
# Epoch 32/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3291 - accuracy: 0.8704
# Epoch 33/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3196 - accuracy: 0.8697
# Epoch 34/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3221 - accuracy: 0.8816
# Epoch 35/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3175 - accuracy: 0.8749
# Epoch 36/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3105 - accuracy: 0.8846
# Epoch 37/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.3021 - accuracy: 0.8816
# Epoch 38/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3058 - accuracy: 0.8816
# Epoch 39/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3004 - accuracy: 0.8928
# Epoch 40/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.8898
# Epoch 41/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2994 - accuracy: 0.8935
# Epoch 42/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2872 - accuracy: 0.8950
# Epoch 43/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2838 - accuracy: 0.8995
# Epoch 44/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2919 - accuracy: 0.8958
# Epoch 45/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2821 - accuracy: 0.9032
# Epoch 46/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2733 - accuracy: 0.9032
# Epoch 47/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2865 - accuracy: 0.9002
# Epoch 48/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.9010
# Epoch 49/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.8995
# Epoch 50/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2676 - accuracy: 0.9032
# Epoch 51/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2679 - accuracy: 0.9114
# Epoch 52/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2632 - accuracy: 0.9054
# Epoch 53/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2738 - accuracy: 0.9084
# Epoch 54/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2536 - accuracy: 0.9114
# Epoch 55/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2657 - accuracy: 0.9054
# Epoch 56/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2660 - accuracy: 0.9002
# Epoch 57/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2514 - accuracy: 0.9166
# Epoch 58/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2586 - accuracy: 0.9173
# Epoch 59/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2492 - accuracy: 0.9114
# Epoch 60/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2509 - accuracy: 0.9069
# Epoch 61/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2515 - accuracy: 0.9106
# Epoch 62/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2441 - accuracy: 0.9181
# Epoch 63/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.9144
# Epoch 64/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2384 - accuracy: 0.9211
# Epoch 65/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2340 - accuracy: 0.9159
# Epoch 66/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2353 - accuracy: 0.9211
# Epoch 67/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2447 - accuracy: 0.9144
# Epoch 68/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.2311 - accuracy: 0.9159
# Epoch 69/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2230 - accuracy: 0.9203
# Epoch 70/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2285 - accuracy: 0.9203
# Epoch 71/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2238 - accuracy: 0.9241
# Epoch 72/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2240 - accuracy: 0.9226
# Epoch 73/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9278
# Epoch 74/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2164 - accuracy: 0.9241
# Epoch 75/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2120 - accuracy: 0.9322
# Epoch 76/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2171 - accuracy: 0.9270
# Epoch 77/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9367
# Epoch 78/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2070 - accuracy: 0.9278
# Epoch 79/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1907 - accuracy: 0.9352
# Epoch 80/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1976 - accuracy: 0.9345
# Epoch 81/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2031 - accuracy: 0.9293
# Epoch 82/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1999 - accuracy: 0.9345
# Epoch 83/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1888 - accuracy: 0.9382
# Epoch 84/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1862 - accuracy: 0.9419
# Epoch 85/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.9397
# Epoch 86/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1916 - accuracy: 0.9404
# Epoch 87/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1967 - accuracy: 0.9330
# Epoch 88/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1956 - accuracy: 0.9345
# Epoch 89/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1871 - accuracy: 0.9367
# Epoch 90/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1781 - accuracy: 0.9404
# Epoch 91/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1809 - accuracy: 0.9419
# Epoch 92/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9464
# Epoch 93/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1798 - accuracy: 0.9427
# Epoch 94/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1737 - accuracy: 0.9389
# Epoch 95/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9404
# Epoch 96/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1784 - accuracy: 0.9427
# Epoch 97/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1802 - accuracy: 0.9442
# Epoch 98/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1758 - accuracy: 0.9471
# Epoch 99/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1669 - accuracy: 0.9464
# Epoch 100/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1667 - accuracy: 0.9464
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.9018
#
# loss: 28.28%
#
# accuracy: 90.18%
